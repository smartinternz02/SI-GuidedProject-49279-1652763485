# %%
# !pwd
# Out:
# /home/wsuser/work

# %% [markdown]
# # Image Processing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1/255,zoom_range=0.2,horizontal_flip=True,rotation_range=180,vertical_flip=False)

# %%
test_datagen = ImageDataGenerator(rescale=1/255)

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_f8e98c5a7d9d496d9de856422a621bd0 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='8rxH2vNTvVxdGpy8ZXGeWkueNF_JlQu5pUQYBpuPTbcl',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

streaming_body_1 = client_f8e98c5a7d9d496d9de856422a621bd0.get_object(Bucket='smartbridgeforestproject-donotdelete-pr-ieewd1lq0sktlv', Key='Forest_Dataset.zip')['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/

# %%
# Unzip the Dataset into local directory
from io import BytesIO
import zipfile
unzip = zipfile.ZipFile(BytesIO(streaming_body_1.read()), 'r')
file_paths = unzip.namelist()
for path in file_paths:
    unzip.extract(path)

# %%
# %%bash
# ls
# Out:
# Dataset
# Emerging_forest_fire_detection.tar.gz
# Emerging-Forest-Fires.tgz
# forestfire.h5

# %%
x_train=train_datagen.flow_from_directory(r'/home/wsuser/work/Dataset/train_set',target_size=(128,128),class_mode = 'binary',batch_size=32)
# Out:
# Found 436 images belonging to 2 classes.

# %%
x_test=test_datagen.flow_from_directory(r'/home/wsuser/work/Dataset/test_set',target_size=(128,128),class_mode = 'binary',batch_size=32)
# Out:
# Found 121 images belonging to 2 classes.

# %%
print("len(x_train) : ", len(x_train))
print("len(x_test) : ", len(x_test))
# Out:
# len(x_train) :  14
# len(x_test) :  4

# %%
x_train.class_indices
# Out:
# {'forest': 0, 'with fire': 1}

# %%
x_test.class_indices
# Out:
# {'forest': 0, 'with fire': 1}

# %% [markdown]
# # MODEL BUILDING

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Flatten,Dense

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
model = Sequential()

# %%
model.add(Convolution2D(32,(3,3),activation='relu',input_shape=(128,128,3)))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())

# %%
#hidden layer - 1
#model.add(Dense(300,activation = 'relu'))

# %%
#hiddenlayer - 2
#model.add(Dense(150,activation='relu'))

# %%
#output layer
#model.add(Dense(2,activation='sigmoid'))

# %%
#model.add(Dense(output_dim=150,init='uniform',activation='relu'))

# %%
#model.add(Dense(output_dim=1,activation='sigmoid',init='uniform'))

# %%
model.add(Dense(kernel_initializer='uniform',activation='relu',units=150))

# %%
model.add(Dense(kernel_initializer='uniform',activation='sigmoid',units=1))

# %%
model.compile(loss='binary_crossentropy',optimizer="adam",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  flatten (Flatten)           (None, 127008)            0
#
#  dense (Dense)               (None, 150)               19051350
#
#  dense_1 (Dense)             (None, 1)                 151
#
# ...
# Total params: 19,052,397
# Trainable params: 19,052,397
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit_generator(x_train,steps_per_epoch=14,epochs=10,validation_data=x_test,validation_steps=4)
# Out:
# Epoch 1/10
# 14/14 [==============================] - 34s 2s/step - loss: 0.9760 - accuracy: 0.6789 - val_loss: 0.2242 - val_accuracy: 0.9174
# Epoch 2/10
# 14/14 [==============================] - 30s 2s/step - loss: 0.2732 - accuracy: 0.8784 - val_loss: 0.1809 - val_accuracy: 0.9091
# Epoch 3/10
# 14/14 [==============================] - 30s 2s/step - loss: 0.2319 - accuracy: 0.8876 - val_loss: 0.1500 - val_accuracy: 0.9587
# Epoch 4/10
# 14/14 [==============================] - 30s 2s/step - loss: 0.1878 - accuracy: 0.9243 - val_loss: 0.0989 - val_accuracy: 0.9669
# Epoch 5/10
# 14/14 [==============================] - 30s 2s/step - loss: 0.1663 - accuracy: 0.9312 - val_loss: 0.1522 - val_accuracy: 0.9421
# Epoch 6/10
# 14/14 [==============================] - 29s 2s/step - loss: 0.1656 - accuracy: 0.9289 - val_loss: 0.0860 - val_accuracy: 0.9669
# Epoch 7/10
# ...

# %%
model.save('forestfire.h5')

# %%
# !tar -zcvf Emerging-Forest-Fires.tgz forestfire.h5
# Out:
# forestfire.h5

# %%
ls -1
# Out:
# Dataset/
# Emerging_forest_fire_detection.tar.gz
# Emerging-Forest-Fires.tgz
# forestfire.h5

# %%
# !pip install watson-machine-learning-client --upgrade

# %%
from ibm_watson_machine_learning import APIClient
wml_credentials= {
 "url": "https://us-south.ml.cloud.ibm.com",
 "apikey":"2t-QIUMBjaRhfhx7yrcyNoZlCbN80pkaQUgLWf3SntPq"
}
client = APIClient(wml_credentials)
#2t-QIUMBjaRhfhx7yrcyNoZlCbN80pkaQUgLWf3SntPq

# %%
def guid_from_space_name(client,space_name):
    space = client.spaces.get_details()
    return(next(item for item in space['resources'] if item['entity']["name"] == space_name)['metadata']['id'])

# %%
space_uid = guid_from_space_name(client,'Forest_fire')
print("Space UID =" +space_uid)
# Out:
# Space UID =e6664ce4-1184-474e-a115-1098efd6b6f9

# %%
client.set.default_space(space_uid)
# Out:
# 'SUCCESS'

# %%
client.software_specifications.list()
# Out:
# -----------------------------  ------------------------------------  ----
# NAME                           ASSET_ID                              TYPE
# default_py3.6                  0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base
# kernel-spark3.2-scala2.12      020d69ce-7ac1-5e68-ac1a-31189867356a  base
# pytorch-onnx_1.3-py3.7-edt     069ea134-3346-5748-b513-49120e15d288  base
# scikit-learn_0.20-py3.6        09c5a1d0-9c1e-4473-a344-eb7b665ff687  base
# spark-mllib_3.0-scala_2.12     09f4cff0-90a7-5899-b9ed-1ef348aebdee  base
# pytorch-onnx_rt22.1-py3.9      0b848dd4-e681-5599-be41-b5f6fccc6471  base
# ai-function_0.1-py3.6          0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base
# shiny-r3.6                     0e6e79df-875e-4f24-8ae9-62dcc2148306  base
# tensorflow_2.4-py3.7-horovod   1092590a-307d-563d-9b62-4eb7d64b3f22  base
# pytorch_1.1-py3.6              10ac12d6-6b30-4ccd-8392-3e922c096a92  base
# tensorflow_1.15-py3.6-ddl      111e41b3-de2d-5422-a4d6-bf776828c4b7  base
# ...

# %%
software_spec_uid = client.software_specifications.get_uid_by_name("tensorflow_rt22.1-py3.9")
software_spec_uid
# Out:
# 'acd9c798-6974-5d2f-a657-ce06e986df4d'

# %%
model_details = client.repository.store_model(model='Emerging-Forest-Fires.tgz',meta_props={client.repository.ModelMetaNames.NAME:"CNN", client.repository.ModelMetaNames.TYPE:"keras_2.2.5", client.repository.ModelMetaNames.SOFTWARE_SPEC_UID:software_spec_uid})
model_id=client.repository.get_model_uid(model_details)
# Out:
# Note: Warnings!! :  Model type keras_2.2.5 is deprecated. We recommend you use a supported model type. See Supported Frameworks https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/pm_service_supported_frameworks.html
# This method is deprecated, please use get_model_id()

# %%
model_id
# Out:
# '3c8d4783-9b6e-41c9-bfd0-bc1c001033f2'

# %%
client.repository.download(model_id, 'Emerging_forest_fire_detection.tar.gz')
# Out:
# File with name: 'Emerging_forest_fire_detection.tar.gz' already exists.
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# /tmp/wsuser/ipykernel_2229/2210554326.py in <module>
# ----> 1 client.repository.download(model_id, 'Emerging_forest_fire_detection.tar.gz')
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/ibm_watson_machine_learning/repository.py in download(self, artifact_uid, filename, rev_uid, format)
#     900
#     901         if res['model'] is True:
# --> 902             return self._client._models.download(artifact_uid, filename, rev_uid,format)
#     903         elif res['function'] is True:
#     904             return self._client._functions.download(artifact_uid, filename, rev_uid)
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/ibm_watson_machine_learning/models.py in download(self, model_uid, filename, rev_uid, format)
# ...
